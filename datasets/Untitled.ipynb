# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('finalAndRatings.csv')

# %%
df = df.iloc[:, 4:]

# %%
df.to_csv('podcasts.csv')

# %%
df
# Out:
#                        podcast_name  \
# 0                      Dateline NBC
# 1                         SmartLess
# 2                         The Daily
# 3             Stuff You Should Know
# 4       Wait Wait... Don't Tell Me!
# ...                             ...
# 14199            How To Buy a House
# 14200              Circular economy
# 14201  Stylist in Your Back Pocket
# 14202        Far Fetched Adventures
# 14203             Poetry in Process
#
#                                             podtail_link   itunes_id  \
# 0              https://podtail.com/podcast/dateline-nbc/  1464919521
# 1                 https://podtail.com/podcast/smartless/  1521578868
# 2                 https://podtail.com/podcast/the-daily/  1200361736
# 3      https://podtail.com/podcast/stuff-you-should-k...   278981407
# 4      https://podtail.com/podcast/npr-programs-wait-...   121493804
# ...                                                  ...         ...
# ...
